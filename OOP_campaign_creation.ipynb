# %%
# Imports
#########
import pandas as pd
import random

# Import the config file containing subjects for each department etc for prompting
# include information in config about

# %%
class Recipient:
    """

    """
    def __init__(self, name: str, surname: str, email: str, department: str) -> None:
        """

        """
        self.name = name
        self.surname = surname
        self.email = email
        self.department = department

class RecipientGroup:
    """

    """
    def __init__(self, recipients: list, department: str) -> None:
        """

        """
        self.recipient_list = recipients
        self.department = department
    
    def create_recipients(self) -> None:
        """
        Create instances of Recipient class for each recipient in list.
        """
        for recipient in self.recipient_list:
            pass
    def create_target_group_gp(self) -> None:
        """
        Create a CSV file with the target group, ready for Gophish.
        """
        pass

class Campaign:
    """

    """
    def __init__(self) -> None:
        """

        """
        pass

    def create_campaign_gp(self) -> None:
        """
        Create a campaign in Gophish.
        """
        pass
    
class EmailGenerator:
    """

    """
    def __init__(self, department: str) -> None:
        """

        """
        self.department = department
        self.random_select_model()
        self.select_email_generator()
        
    def random_select_model(self) -> None:
        """
        Randomly select an AI model for mail generation.
        """
        self.model = random.choice(["OpenAI", "Gemini"])

    def select_email_generator(self) -> None:
        """
        Select the email generator based on the model.
        """
        if self.model == "OpenAI":
            self.generate_OpenAI_email()
        elif self.model == "Gemini":
            self.generate_Gemini_email()
        else:
            pass

    def generate_OpenAI_email(self) -> None:
        """
        Generate an email using OpenAI.
        """
        pass

    def generate_Gemini_email(self) -> None:
        """
        Generate an email using Gemini.
        """
        pass

    def create_email_gp(self) -> None:
    """
    Create an email to send to Gophish.
    """
    pass

# %%
class Campaign:
    """

    """
    def __init__(self):
        self.department_list = []
        self.import_recipients()


    def import_recipients(self, path: str):
        """
        Import phishing campaign recipients from a CSV file. Setup department/role list.

        :param path: str: Path to the CSV file containing the recipients.
        """
        # Read the CSV file
        recipients = pd.read_csv(path)
        # Convert the DataFrame to a dictionary of dictionaries
        recipients_dict = recipients.to_dict(orient="index")
        # Extract distinct department names
        distinct_departments = set()  # Use a set to avoid duplicates
        for recipient in recipients_dict.values():
            distinct_departments.add(recipient["department"])

        # Convert the set back to a list if needed
        distinct_departments_list = list(distinct_departments)

        for index, target in targets.iterrows():
    email_content = generate_phishing_email(
        target['name'],
        target['surname'],
        target['email'],
        target['role'],
        target['department'],
        target['interest']
    )

# %%
import random
import gemini_utils as gemini
import openai_utils as openai

class EmailGenerator:
    """

    """
    def __init__(self, department: str) -> None:
        """

        """
        self.department = department
        self.random_select_model()
        self.select_email_generator()
        
    def random_select_model(self) -> None:
        """
        Randomly select an AI model for mail generation.
        """
        self.model = random.choice(["OpenAI", "Gemini"])

    def select_email_generator(self) -> None:
        """
        Select the email generator based on the model.
        """
        if self.model == "OpenAI":
            self.generate_OpenAI_email()
        elif self.model == "Gemini":
            self.generate_Gemini_email()
        else:
            pass

    def generate_OpenAI_email(self) -> None:
        """
        Generate an email using OpenAI.
        """
        print("Generating email using OpenAI...")
        openai.load_env()
        openai.load_prompts()
        
        self.mail_body = openai.generate_mail_body_openai(self.department)
        self.mail_subject = openai.generate_mail_subject_openai(self.mail_body)

    def generate_Gemini_email(self) -> None:
        """
        Generate an email using Gemini.
        """
        print("Generating email using Gemini...")
        gemini.load_env()
        gemini.load_prompts()

        self.mail_body = gemini.generate_mail_body_gemini(self.department)
        self.mail_subject = gemini.generate_mail_subject_gemini(self.mail_body)

    def create_email_gp(self) -> None:
        """
        Create an email to send to Gophish.
        """
        pass

# %%
HR_email = EmailGenerator(department= "HR")
print(HR_email.mail_subject)
print(HR_email.mail_body)
# Out:
# Generating email using Gemini...
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 HR_email = EmailGenerator(department= "HR")
#       2 print(HR_email.mail_subject)
#       3 print(HR_email.mail_body)
#
# Cell In[4], line 15, in EmailGenerator.__init__(self, department)
#      13 self.department = department
#      14 self.random_select_model()
# ---> 15 self.select_email_generator()
#
# Cell In[4], line 30, in EmailGenerator.select_email_generator(self)
#      28     self.generate_OpenAI_email()
#      29 elif self.model == "Gemini":
# ---> 30     self.generate_Gemini_email()
#      31 else:
#      32     pass
#
# Cell In[4], line 53, in EmailGenerator.generate_Gemini_email(self)
#      50 gemini.load_env()
#      51 gemini.load_prompts()
# ---> 53 self.mail_body = gemini.generate_mail_body_gemini(self.department)
#      54 self.mail_subject = gemini.generate_mail_subject_gemini(self.mail_body)
#
# File c:\Users\kvnpo\Desktop\DataScience\BeCode\Projects\8-phishing-analysis\gemini_utils.py:62, in generate_mail_body_gemini(department)
#      57 # Generate the mail body
#      58 # Use the Gemini API to generate the mail body
#      59 model=genai.GenerativeModel(
#      60 model_name="gemini-1.5-pro",
#      61 system_instruction=developer_message)
# ---> 62 mail_body = model.generate_content(user_prompt.format(department=department))
#      64 return mail_body.text
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:830, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     827 self._validate_universe_domain()
#     829 # Send the request.
# --> 830 response = rpc(
#     831     request,
#     832     retry=retry,
#     833     timeout=timeout,
#     834     metadata=metadata,
#     835 )
#     837 # Done; return the response.
#     838 return response
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File c:\Users\kvnpo\anaconda3\envs\phishing-analysis-env\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
